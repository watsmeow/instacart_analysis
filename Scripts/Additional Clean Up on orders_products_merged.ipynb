# %%
# Importing libraries and data

import pandas as pd
import numpy as np
import os

# %%
path = r'C:\Users\anon\Documents\CareerFoundry\Data Analytics Immersion\Instacart Basket Analysis'

# %%
ords_prods_merged = pd.read_pickle(os.path.join(path, 'Data', 'Prepared Data', 'orders_products_merged_inner.pkl'))

# %%
ords_prods_merged.rename(columns={'order_dow': 'orders_day_of_the_week'}, inplace=True)

# %%
ords_prods_merged.head()
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_the_week  \
# 0   2539329        1    prior             1                       2
# 1   2398795        1    prior             2                       3
# 2    473747        1    prior             3                       3
# 3   2254736        1    prior             4                       4
# 4    431534        1    prior             5                       4
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  7                    15.0         196                  1
# 2                 12                    21.0         196                  1
# 3                  7                    29.0         196                  1
# 4                 15                    28.0         196                  1
#
#    reordered product_name  aisle_id  department_id  prices _merge
# ...

# %%
ords_prods_merged.drop(columns=['eval_set'], inplace=True)

# %%
ords_prods_merged
# Out:
#           order_id  user_id  order_number  orders_day_of_the_week  \
# 0          2539329        1             1                       2
# 1          2398795        1             2                       3
# 2           473747        1             3                       3
# 3          2254736        1             4                       4
# 4           431534        1             5                       4
# ...            ...      ...           ...                     ...
# 32404854   1320836   202557            17                       2
# 32404855     31526   202557            18                       5
# 32404856    758936   203436             1                       2
# 32404857   2745165   203436             2                       3
# 32404858   3093936   205420             1                       4
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                         8                     NaN         196
# ...

# %%
# Export data to pkl

ords_prods_merged.to_pickle(os.path.join(path, 'Data','Prepared Data', 'orders_products_merged.pkl'))
